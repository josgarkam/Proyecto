# %% [markdown]
# <a href="https://colab.research.google.com/github/josgarkam/Git.-Taller-de-introducci-n/blob/main/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
from wordcloud import WordCloud#, STOPWORDS
from os import path
from PIL import Image
import numpy as np

id = "Candid Moe"
print("ingrese el ID del Usuario de Stark Overflow por defecto: ")
i=input()

if i == id :
  
    print("Se comenso a generar la nube de palabras")
    game =path.dirname("nubeDePalabras.json")

    #Lectura del y escritura del archivo de datos
    with open ("nubeDePalabras.json") as file:#,encoding= "utf-8"
        text = file.read()

    #Impresión de la nube de datos con parametros definidos
    wc = WordCloud(background_color="black",
		max_words=200,
		height=1600, width=1720,)
    wc.generate(text)
    wc.to_file(path.join(game,"wordcloud.png"))

    # the matplotlib way:
    import matplotlib.pyplot as plt
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")

    # lower max_font_size
    wc = WordCloud(max_font_size=100).generate(text)
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()


else:
   print("El ID está mal escrito")
   print("Intente de nuevo")
# Out:
# ingrese el ID del Usuario de Stark Overflow por defecto:
# Candid Moe
# Se comenso a generar la nube de palabras
